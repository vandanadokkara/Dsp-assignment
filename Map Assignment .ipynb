# %%
import folium

# %%
way1=[[16.78001,80.849998],[16.7850,80.8488],[16.6356,80.9716],[17.0005,81.8040],[17.2789,82.4013],[17.6868,83.2185],
     [17.9325,83.4268],[18.2949,83.8938],[18.7747,84.4094]]
way2=[[16.780001,80.849998],[16.5062,80.6480],[16.6356, 80.9716]]

# %%
from branca.element import Figure
fig=Figure()

# %%
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")
map=folium.Map(location=[16.780001,80.849998],tiles='cartodbpositron')
line_1=folium.vector_layers.PolyLine(way1,popup='<b> Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(way2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)

folium.Marker(location=[16.7850,80.8488],popup='Starting point',tooltip='Nuzvidu',icon=folium.Icon(color='blue',prefix='fa',icon='university')).add_to(map)
folium.Marker(location=[17.0005,81.8040],tooltip='Rajamahendravaram',icon=folium.Icon(color='purple',prefix='glyphicon',icon='bell')).add_to(map)
folium.Marker(location=[17.6868,83.2185],tooltip='Vishakhapatnam',icon=folium.Icon(color='blue',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[17.9325,83.4268],popup='Default popup Marker6',tooltip='Thagarapuvalasa').add_to(map)
folium.Marker(location=[18.2949,83.8938],popup='Default popup Marker7',tooltip='Sriakakulam').add_to(map)
folium.Marker(location=[18.7747,84.4094],popup='Destination',tooltip='Palasa',icon=folium.Icon(color='blue',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[16.5062,80.6480],popup='Defalut popup Marker9',tooltip='kanakadurgamma temple').add_to(map)
folium.Marker(location=[16.6356,80.9716],popup='Default popup Marker10',tooltip='Hanuman junction').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
